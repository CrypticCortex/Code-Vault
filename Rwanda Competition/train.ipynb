# %%
import pandas as pd

# %%
data_org = pd.read_csv('train.csv')

# %%
data = data_org

# %%
data.dropna()
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 155    ID_-0.510_29.290_2021_49    -0.510     29.290  2021       49
# 451    ID_-0.547_29.653_2021_27    -0.547     29.653  2021       27
# 453    ID_-0.547_29.653_2021_29    -0.547     29.653  2021       29
# 474    ID_-0.547_29.653_2021_50    -0.547     29.653  2021       50
# 1112   ID_-0.615_30.885_2021_52    -0.615     30.885  2021       52
# ...                         ...       ...        ...   ...      ...
# 78045  ID_-3.136_30.364_2021_29    -3.136     30.364  2021       29
# 78203  ID_-3.138_30.662_2021_28    -3.138     30.662  2021       28
# 78205  ID_-3.138_30.662_2021_30    -3.138     30.662  2021       30
# 78216  ID_-3.138_30.662_2021_41    -3.138     30.662  2021       41
# 78858  ID_-3.287_29.713_2021_47    -3.287     29.713  2021       47
#
#        SulphurDioxide_SO2_column_number_density  \
# 155                                    0.000024
# 451                                    0.000084
# ...

# %%
import pycaret

# %%
#using pycaret
